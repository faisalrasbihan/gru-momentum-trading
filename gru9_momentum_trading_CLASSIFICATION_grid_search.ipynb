# %% [markdown]
# <a href="https://colab.research.google.com/github/faisalrasbihan/gru-momentum-trading/blob/main/gru9_momentum_trading_CLASSIFICATION_grid_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Preamble

# %%
import pandas as pd
import numpy as np
import datetime as dt
from numpy import ones,vstack
from numpy.linalg import lstsq
import missingno as msno
from tqdm import tqdm

# Machine Learning
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation, Dropout, LSTM, Conv1D, GRU
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow.keras.backend as K

# Data Visualizations
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

from itertools import combinations_with_replacement 
import multiprocessing

# Math & Stats
from sklearn.model_selection import cross_val_score, TimeSeriesSplit
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import StackingRegressor
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler,RobustScaler, PowerTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score, recall_score
from scipy import stats

# Import custom utility funciton 
import _data_processor as dp
import _visualize as viz
import _predict_model as pm
import _trade_simulation as tm

sns.set()

# %% [markdown]
# # 1. Import Data

# %%
# Read CSV - LQ45 Historical Data
df = pd.read_csv('dataset/LQ45_20210309.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df = df.set_index('Date').sort_index().rename(columns={"Price": "Close"})
df.drop(['LQ45_Vol'],axis=1,inplace=True)

# read IDX30 data
IDX30 = pd.read_csv('dataset/IDX30_20210309.csv').rename(columns={"IDX30_Vol": "Volume"})
IDX30['Date'] = pd.to_datetime(IDX30['Date'], format='%d/%m/%Y')
IDX30 = IDX30.set_index('Date').sort_index().rename(columns={"Price": "IDX30"})

# read IHSG data
IHSG = pd.read_csv('dataset/IHSG_20210309.csv')
IHSG['Date'] = pd.to_datetime(IHSG['Date'], format='%d/%m/%Y')
IHSG = IHSG.set_index('Date').sort_index().rename(columns={"Price": "IHSG"})

IDX30.replace(0, np.nan, inplace=True)
IDX30['Volume'] = IDX30['Volume']/1000000000
IDX30.loc[IDX30.Volume > 13, 'Volume'] = np.nan

IDX30 = IDX30[['IDX30','Volume']]
IHSG = IHSG[['IHSG']]

# read EIDO data
EIDO = pd.read_csv('dataset/EIDO_20210309.csv')
EIDO['Date'] = pd.to_datetime(EIDO['Date'], format='%d/%m/%Y')
EIDO = EIDO.set_index('Date').sort_index().rename(columns={"Price": "EIDO"})

# read SPY data
SPY = pd.read_csv('dataset/SPY_20210309.csv')
SPY['Date'] = pd.to_datetime(SPY['Date'], format='%d/%m/%Y')
SPY = SPY.set_index('Date').sort_index().rename(columns={"Price": "SPY"})

SPY = SPY[['SPY']]#.resample('D').mean().shift(1).fillna(method='ffill')
EIDO = EIDO[['EIDO']]#.resample('D').mean().shift(1).fillna(method='ffill')

# %%
jci_value = pd.read_csv('dataset/JCI_value.csv')
jci_value['date'] = pd.to_datetime(jci_value['date'], format='%d/%m/%Y')
jci_value = jci_value.set_index('date').sort_index()

# %%
df = df.merge(SPY, how='outer', left_index=True, right_index=True).copy()
df = df.merge(EIDO, how='outer', left_index=True, right_index=True).copy()
df = df.merge(IHSG, how='left', left_index=True, right_index=True).copy()
df = df.merge(IDX30, how='left', left_index=True, right_index=True).copy()
df = df.merge(jci_value[['for_flow','dom_total','tot_buy']], how='left', left_index=True, right_index=True).copy()

# %% [markdown]
# # 2. Helper Functions

# %%
def sign_accuracy(true,pred):
    true = (true*STD) + MEAN
    pred = (pred*STD) + MEAN
    return K.mean(K.equal(K.sign(true), K.sign(pred)))

# %%
def generate_prediction(m, X, y, dates=dt.datetime(2012, 5, 1)):
    pred = m.predict(X)[:,0]
    true = y[:,0]
    train_result = pm.bundle_predicted_actual(true,pred)
    train_result['mse'] = np.abs(train_result['true'] - train_result['pred']).rolling(7).sum()
    train_result['squared_hinge'] = 1 - train_result['true'] * train_result['pred']
    train_result.loc[train_result['squared_hinge'] < 0,'squared_hinge'] = 0
    train_result['squared_hinge'] = train_result['squared_hinge']**2
    train_result['rolling_error'] = train_result['squared_hinge'].rolling(7).mean()
    train_result['date'] = dates
    train_result['date_str'] = train_result['date'].dt.strftime('%Y-%m-%d')
    train_result['date_to_val'] = train_result['date'].map(pd.Series(data=np.arange(len(train_result)), 
                                                                     index=train_result['date'].values).to_dict())
    return pred,true,train_result

# %%
def create_model(neurons,output_timesteps,shape1,shape2,loss_function):
    model = tf.keras.Sequential()
    model.add(GRU(neurons, activation='linear', input_shape=(shape1,shape2)))
    model.add(Dense(output_timesteps, activation='tanh'))
    model.compile(optimizer='adam', loss=loss_function, metrics=[sign_accuracy])
    return model

# %%
def multi_gru_model(neurons,output_timesteps,shape1,shape2,loss_function):
    model = tf.keras.Sequential()
    model.add(GRU(50, return_sequences=True, activation='linear', input_shape=(shape1,shape2)))
    model.add(Dropout(0.2))
    model.add(GRU(50, activation='linear'))
    model.add(Dropout(0.2))
    model.add(Dense(output_timesteps, activation='tanh'))
    model.compile(optimizer='adam', loss=loss_function, metrics=[sign_accuracy])
    return model

# %%
def multi_layer_model(gru_neurons,hidden_neurons,output_timesteps,shape1,shape2,loss_function):
    model = tf.keras.Sequential()
    model.add(GRU(gru_neurons, activation='linear', input_shape=(shape1,shape2)))
    model.add(Dense(hidden_neurons, activation='tanh'))
    model.add(Dense(1, activation='tanh'))
    model.compile(optimizer='adam', loss=loss_function, metrics=[sign_accuracy])
    return model

# %%
MEAN_pre_filtered = 0.06968521192214656
STD_pre_filtered = 2.3073312870270306

def target_inverse_transform(x, mean=MEAN_pre_filtered, std=STD_pre_filtered):
    return (x*STD) + MEAN

def target_transform(x, mean=MEAN_pre_filtered, std=STD_pre_filtered):
    return (x - MEAN)/STD

# %%
def train_test_date_split(df_orig, range1='2020-01-01', range2='2019-01-01', range3='2020-01-01', range4='2021-02-01'):
    df = df_orig.copy()
    df_train = df[(df.index < range1)].copy()
    df_test = df[(df.index >= range2) & (df.index < range3)].copy()
    df_test2 = df[(df.index >= range3) & (df.index < range4)].copy()
    return df_train, df_test, df_test2

# %%
def plot_all(df, cols):
    fig, ax = plt.subplots(len(cols), 2, figsize=(18,len(cols)*4), gridspec_kw={'width_ratios': [1, 3]})
    colors = sns.color_palette()
    colors += colors
    for i, col in enumerate(cols):
        sns.histplot(df[col], ax=ax[i,0], color=colors[i])
        ax[i,1].plot(df.index, df[col], color=colors[i])
        ax[i,1].set_title(col)
        ax[i,0].grid()
#         ax[i,0].set_ylim(0,ylim)
    plt.tight_layout()

# %%
def hampel(vals_orig, k=7, t0=3):
    #Make copy so original not edited
    vals = vals_orig.copy()
    
    #Hampel Filter
    L = 1.4826
    rolling_median = vals.rolling(window=k, center=True).median()
    MAD = lambda x: np.median(np.abs(x - np.median(x)))
    rolling_MAD = vals.rolling(window=k, center=True).apply(MAD)
    threshold = t0 * L * rolling_MAD
    difference = np.abs(vals - rolling_median)
    
    outlier_idx = difference > threshold
    vals[outlier_idx] = rolling_median[outlier_idx] 
    return outlier_idx, vals

# %% [markdown]
# # 3. Feature Engineering

# %%
# Filter volume
outlier_idx, dom_filtered = hampel(df.dom_total,k=20,t0=9)
dom_outlier = df.dom_total.copy()
dom_outlier[~outlier_idx] = np.nan
df['dom_filtered'] = dom_filtered

outlier_idx, for_filtered = hampel(df.for_flow,k=20,t0=9)
for_outlier = df.for_flow.copy()
for_outlier[~outlier_idx] = np.nan
df['for_flow_filtered'] = for_filtered

outlier_idx, total_buy_filtered = hampel(df.tot_buy,k=20,t0=9)
tot_outlier = df.tot_buy.copy()
tot_outlier[~outlier_idx] = np.nan
df['total_buy_filtered'] = total_buy_filtered

# %%
# Resample Date to fill missing date
df = df.resample('D').mean()

# Interpolate Close and Volume Values
df.interpolate(inplace=True)

# Remove saturday and sunday data
df['day_of_week'] = df.index.dayofweek + 1
df = df[df['day_of_week'] < 6].copy()
df.drop(columns=['day_of_week'],inplace=True)

df = df[df.index >= '2012-04-24'].copy()

# %% [markdown]
# ## 3.3 Create Engineered Features

# %%
MA_PERIOD = 5
FUTURE_DAYS = 3

df['momentum'] = dp.momentum_transformation(df, 'Close', ma_span=MA_PERIOD, normalized=False)
# df['price_volatility'] = df['1day_price_change'].rolling(10).std()
df['linear_series'] = (df.reset_index().index + 1000) / 1000
df['target'] = df['Close'].pct_change(periods=FUTURE_DAYS).shift(-(FUTURE_DAYS)) * 100

df['EIDO'] = 100*df['EIDO']/df['EIDO'][0]
df['SPY'] = 100*df['SPY']/df['SPY'][0]
df['EIDO_SPY_diff'] = df['EIDO'] - df['SPY']
df['EIDO_SPY_ma'] = df['EIDO_SPY_diff'].rolling(7).mean()

df['IDX30'] = 100*df['IDX30']/df['IDX30'][0]
df['IHSG'] = 100*df['IHSG']/df['IHSG'][0]
df['IDX30_IHSG_diff'] = df['IDX30'] - df['IHSG']
df['IDX30_IHSG_ma'] = df['IDX30_IHSG_diff'].rolling(7).mean()

df['dom_filtered'] = df['dom_filtered'] / (10**6)
df['for_flow_filtered'] = df['for_flow_filtered'] / (10**6)
df['total_buy_filtered'] = df['total_buy_filtered']/(10**6)

df['dom_val_ma'] = df['dom_filtered'].rolling(7).mean()
df['for_flow_ma'] = df['for_flow_filtered'].rolling(7).mean()
df['total_val_grad'] = df['total_buy_filtered'].rolling(3).mean() - df['total_buy_filtered'].rolling(11).mean().shift(3)

# %% [markdown]
# ## 3.1 Remove outliers on target

# %%
# Remove outliers
df = df[(df['target'] < 3*STD_pre_filtered) & (df['target'] > -3*STD_pre_filtered)]

# Determine mean and standard deviation
MEAN = np.mean(df['target'].values)
STD = np.std(df['target'].values)
print('Mean: ', MEAN)
print('STD: ', STD)

# Plot result
fig = px.histogram(df, x="target",
                   marginal="box", # or violin, rug
                   hover_data=df.columns)
fig.show()
# Out:
# Mean:  0.10263738808988873
# STD:  1.907956821190298
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="40938fb1-f6ae-43a5-9c25-de7ce35e713f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("40938fb1-f6ae-43a5-9c25-de7ce35e713f")) {
#                     Plotly.newPlot(
#                         '40938fb1-f6ae-43a5-9c25-de7ce35e713f',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "target=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [-0.22254461456118202, 0.4774011299434999, 0.3117101937657907, 1.4285915950253303, 0.8996598161320257, 0.2519526329050281, -1.639503973500711, -1.06717935857783, -2.351232861411301, -0.9565180479108037, -1.9123528417732238, -1.7901569961966235, -1.9515122076660507, -3.088121285209755, -2.0138019392598183, -2.2269819760749487, -1.4828970564271238, 0.9155636912580256, 0.42680909532566425, 1.365372470000903, -3.1375609181525155, -1.9661962634851426, -1.9551995252929943, 0.9241807016477255, -2.2629571324775832, -2.9489196877080404, -2.654524617076326, 1.761688726751176, 6.07418956668615, 3.6973987749582493, 0.8196344583518478, 0.5496692797648306, 0.9067337639423911, -1.9845611475808544, -0.9836914315299095, 0.013684050478923737, 2.6975907723791437, 3.850826605151858, 1.4807157299442153, 0.21587512454335211, -2.6936575397236706, -0.7070843257980908, 1.3150561120735205, 0.8552731699893457, 1.8074561337336537, 1.567099824556184, 4.970424915499749, 3.7848812223062023, 2.11529453097552, -0.16243567259868197, -2.8243827909699815, -1.6729503849076233, -0.7861431471642533, 0.04555139225628224, 0.18661612479953238, 0.3468442973863395, 2.4116558470169913, 1.561454058616385, 1.2524224105515902, -0.2409362092703038, -2.2180510380994667, -3.1451751128377947, -2.4137435307648225, -0.26376331638409134, 3.061495354667443, 3.458994416699812, 4.7220957054493695, 1.6641387402341001, -0.027054350766764212, -1.264082382816334, -0.9486410786921695, -0.3988035892323105, -0.3694441286802297, 0.885257548845475, 2.0291720291720328, 0.6945632951109504, 0.0, 0.2705013384910693, 1.776128493123541, 1.2098932364291937, 0.4403008023259103, 0.0, -0.03131218948745351, -0.06262437897491813, -0.738967671903934, -0.7148375780439697, -0.8605804043892329, -1.547822673358934, -3.429564924776718, -2.304969519903377, 0.6422488678761606, 2.267876588021789, 0.3234943136888324, -0.4527896084784877, 1.0136717918139526, 2.5681446874373126, 1.5564368257217298, 0.8011131256061121, 0.026547436076551634, 2.5263128429067194, 2.1834609110302328, 1.631535571107312, -0.20203950691439765, -1.0124578711094734, 0.38484269554819317, -1.4499692223513994, 0.04548900682335155, -1.8319481906430957, 0.664862238878472, 0.8253189671801442, 1.256642352055115, 0.7542330814626963, -0.1544201046776994, 1.4283746556473798, 1.9337356817342055, 1.1483083324208998, 0.726536931162336, -0.3692068095161427, 0.37481563671297735, 0.5743407215660801, 0.6077429961325542, 1.1162038285252196, 0.7614145151344509, 1.209482989552635, 0.029330204778155178, 0.08514487933373172, -0.9488770959331871, -0.18925763028121434, -0.358899375249222, 0.08350479651551002, -0.17893387458605137, 0.618996798292426, 0.27166476434583586, 0.02006581587608025, -0.8061094611794717, -1.3619661305783404, -0.674076154556047, 0.3809345594525171, 0.7747438891063441, 0.5817006665320257, -1.059905993262411, -0.2665309457160814, 0.17537518240355876, 0.47156988089631646, 0.025247099269454232, -1.1533115945902561, -0.9060295705334176, -0.6710274049847698, 0.6476035962955651, 0.8948485380986471, 1.6490274792857695, -0.21895653108378044, -1.4107528034190242, -1.8057790247729355, -2.153982848911562, -0.30032070446268655, -1.7970072449048802, 0.12107703526369473, -0.7619229353796553, 0.307509859621069, 0.5455619838117709, 1.1633336995934496, 2.1006035110872956, 0.9621955553125838, -0.0909646324078417, -0.6907323378529506, -0.39935020982808656, -0.5612328096972319, -1.518520527143541, -1.3360516479782536, -0.49497779296207023, 0.3447326394625305, 0.506942913819719, 0.258471038059227, 0.8473460069368111, 1.3829495614035014, 1.5383350913001248, 1.0543643883326181, 1.8169773824169733, 1.7052506610544471, 1.0595188411260281, -0.1208290733339501, -1.229638669284238 ...

# %%
# # Determine 33% and 66% quartile from target
# quantile_33 = np.quantile(df['target'], 0.33)
# quantile_66 = np.quantile(df['target'], 0.66)

# # Set target at 0 for 33-66% quantile
# mask = (df.target > quantile_33) & (df.target < quantile_66)
# df.loc[mask, 'target'] = 0

# # Plot result
# fig = px.histogram(df, x="target",
#                    marginal="box", # or violin, rug
#                    hover_data=df.columns)
# fig.show()

# %% [markdown]
# # 4. Train Model

# %%
slow_and_fast = [(6,6),(7,5),(8,4),(9,3),(9,7),(10,6),(8,6),(9,5),(10,4),(11,3)]
combi = list(combinations_with_replacement(slow_and_fast,3))
highacc_combi = list(combi[i] for i in [4, 14, 21, 28])
highacc_combi
# Out:
# [((6, 6), (6, 6), (9, 7)),
#  ((6, 6), (7, 5), (10, 6)),
#  ((6, 6), (8, 4), (9, 7)),
#  ((6, 6), (9, 3), (9, 7))]

# %%
target_variables = 'target'
input_variables = ['momentum','IDX30_IHSG_grad','EIDO_SPY_grad','total_val_grad','dom_val_ma','for_flow_ma']
neurons = 90
multi_neurons = (20,5)
loss = 'squared_hinge'
input_timesteps = 20
output_timesteps = 1
epochs = 80
validation_split = 0.2
span = 4
d = highacc_combi[1]

# %%
# Final Variables
df2 = df.copy()
df2['momentum'] = dp.momentum_transformation(df2, 'Close', ma_span=span, normalized=False)
df2['EIDO_SPY_grad'] = df2['EIDO_SPY_diff'].rolling(d[0][1]).mean() - df2['EIDO_SPY_diff'].rolling(d[0][0]).mean().shift(d[0][1])
df2['IDX30_IHSG_grad'] = df2['IDX30_IHSG_diff'].rolling(d[1][1]).mean() - df2['IDX30_IHSG_diff'].rolling(d[1][0]).mean().shift(d[1][1])
df2['Volume_grad'] = df2['Volume'].rolling(d[2][1]).mean() - df2['Volume'].rolling(d[2][0]).mean().shift(d[2][1])

df2['target'] = df2['target'].apply(target_transform, mean=MEAN, std=STD) # Standardize target with predetermined constants

# Train test split
df2 = df2.dropna()

# Final Sanity Check
df2[(df2.index > '2020-11-09')][input_variables + [target_variables]]
# Out:
#             momentum  IDX30_IHSG_grad  ...  for_flow_ma    target
# Date                                   ...
# 2020-11-10   25.0850         1.597008  ...     0.458449  0.142151
# 2020-11-11   25.1700         2.720250  ...     0.817652 -0.445685
# 2020-11-12    3.8850         3.346266  ...     0.894226  0.861186
# 2020-11-13   -2.2675         3.563341  ...     0.859133  1.061292
# 2020-11-16    1.6050         3.637999  ...     0.704874  0.767095
# ...              ...              ...  ...          ...       ...
# 2021-02-25   -0.8875        -0.325635  ...     0.167836  0.778161
# 2021-02-26   -7.0550        -0.355907  ...     0.168898  1.248256
# 2021-03-01   13.7875         0.008931  ...     0.173242 -1.096382
# 2021-03-02    9.4925        -0.063408  ...     0.175230 -1.478301
# 2021-03-03    6.1325        -0.047181  ...     0.193781 -1.568961
#
# [82 rows x 7 columns]

# %%
df_train = df2[(df2.index < '2019-01-01')].copy()
df_test = df2[(df2.index >= '2019-01-01') & (df2.index <= '2020-02-01')].copy()
df_test2 = df2[(df2.index >= '2020-01-01') & (df2.index <= '2021-02-01')].copy()
df_test3 = df2[(df2.index >= '2020-01-01') & (df2.index <= '2021-02-01')].copy()

# Unroll data
dates = df_train[(input_timesteps+output_timesteps-1):].index

# Separate train and test data
X_train, y_train = dp.generate_batch(df_train, input_timesteps, output_timesteps, input_variables, target_variables)
######### DELETE LATER #########
lower_thresh = np.quantile(y_train, 0.4)
upper_thresh = np.quantile(y_train, 0.6)
mask = (y_train < lower_thresh) | (y_train > upper_thresh)
X_train = X_train[mask[:,0]]
y_train = y_train[mask[:,0]]
######### DELETE LATER #########
X_test, y_test = dp.generate_batch(df_test, input_timesteps, output_timesteps, input_variables, target_variables)
X_test2, y_test2 = dp.generate_batch(df_test2, input_timesteps, output_timesteps,  input_variables, target_variables)
X_test3, y_test3 = dp.generate_batch(df_test3, input_timesteps, output_timesteps,  input_variables, target_variables)

# Build LSTM Model using Tensorflow
model = create_model(neurons, output_timesteps, X_train.shape[1], X_train.shape[2], loss)
# model = multi_layer_model(multi_neurons[0],multi_neurons[1],output_timesteps,X_train.shape[1], X_train.shape[2],loss)
# model = multi_layer_model(multi_neurons[0],multi_neurons[1],output_timesteps,X_train.shape[1], X_train.shape[2],loss)

model_name = 'gru7_oneoff_n{neurons}_{feature_count}var_span{span}_X1.hdf5'.format(
                                                                                neurons=neurons,
                                                                                span=span,
                                                                                feature_count=len(input_variables))
model_path = 'temp_model/{}'.format(model_name)
mcp_save = ModelCheckpoint(model_path, save_best_only=True, monitor='val_loss', mode='min',verbose=2)

history = model.fit(
    X_train,
    y_train,
    epochs=epochs,
    batch_size=len(X_train),
    validation_split=validation_split,
    verbose = 2, 
    shuffle=True,
    callbacks=[mcp_save]
)

new_model = tf.keras.models.load_model(model_path, compile=False)
# Out:
# Epoch 1/80
# 1/1 - 3s - loss: 1.4397 - sign_accuracy: 0.5180 - val_loss: 1.3965 - val_sign_accuracy: 0.5018
#
# Epoch 00001: val_loss improved from inf to 1.39655, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 2/80
# 1/1 - 0s - loss: 1.2457 - sign_accuracy: 0.5569 - val_loss: 1.3844 - val_sign_accuracy: 0.5018
#
# Epoch 00002: val_loss improved from 1.39655 to 1.38441, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 3/80
# 1/1 - 0s - loss: 1.1838 - sign_accuracy: 0.5393 - val_loss: 1.4560 - val_sign_accuracy: 0.5092
#
# Epoch 00003: val_loss did not improve from 1.38441
# Epoch 4/80
# 1/1 - 0s - loss: 1.1970 - sign_accuracy: 0.5430 - val_loss: 1.4435 - val_sign_accuracy: 0.5129
#
# Epoch 00004: val_loss did not improve from 1.38441
# Epoch 5/80
# 1/1 - 0s - loss: 1.1698 - sign_accuracy: 0.5458 - val_loss: 1.3710 - val_sign_accuracy: 0.4982
#
# Epoch 00005: val_loss improved from 1.38441 to 1.37098, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 6/80
# 1/1 - 0s - loss: 1.1006 - sign_accuracy: 0.5578 - val_loss: 1.2986 - val_sign_accuracy: 0.4723
#
# Epoch 00006: val_loss improved from 1.37098 to 1.29863, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 7/80
# 1/1 - 0s - loss: 1.0703 - sign_accuracy: 0.5680 - val_loss: 1.2552 - val_sign_accuracy: 0.4908
#
# Epoch 00007: val_loss improved from 1.29863 to 1.25518, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 8/80
# 1/1 - 0s - loss: 1.0821 - sign_accuracy: 0.5550 - val_loss: 1.2266 - val_sign_accuracy: 0.4797
#
# Epoch 00008: val_loss improved from 1.25518 to 1.22661, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 9/80
# 1/1 - 0s - loss: 1.0761 - sign_accuracy: 0.5587 - val_loss: 1.1864 - val_sign_accuracy: 0.4871
#
# Epoch 00009: val_loss improved from 1.22661 to 1.18640, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 10/80
# 1/1 - 0s - loss: 1.0375 - sign_accuracy: 0.5819 - val_loss: 1.1531 - val_sign_accuracy: 0.5055
#
# Epoch 00010: val_loss improved from 1.18640 to 1.15311, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 11/80
# 1/1 - 0s - loss: 0.9981 - sign_accuracy: 0.5828 - val_loss: 1.1502 - val_sign_accuracy: 0.5055
#
# Epoch 00011: val_loss improved from 1.15311 to 1.15021, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 12/80
# 1/1 - 0s - loss: 0.9838 - sign_accuracy: 0.5837 - val_loss: 1.1649 - val_sign_accuracy: 0.5203
#
# Epoch 00012: val_loss did not improve from 1.15021
# Epoch 13/80
# 1/1 - 0s - loss: 0.9884 - sign_accuracy: 0.5708 - val_loss: 1.1636 - val_sign_accuracy: 0.5018
#
# Epoch 00013: val_loss did not improve from 1.15021
# Epoch 14/80
# 1/1 - 0s - loss: 0.9857 - sign_accuracy: 0.5698 - val_loss: 1.1351 - val_sign_accuracy: 0.4834
#
# Epoch 00014: val_loss improved from 1.15021 to 1.13510, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 15/80
# 1/1 - 0s - loss: 0.9702 - sign_accuracy: 0.5911 - val_loss: 1.1010 - val_sign_accuracy: 0.4871
#
# Epoch 00015: val_loss improved from 1.13510 to 1.10099, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 16/80
# 1/1 - 0s - loss: 0.9555 - sign_accuracy: 0.5846 - val_loss: 1.0841 - val_sign_accuracy: 0.5240
#
# Epoch 00016: val_loss improved from 1.10099 to 1.08413, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 17/80
# 1/1 - 0s - loss: 0.9503 - sign_accuracy: 0.6022 - val_loss: 1.0835 - val_sign_accuracy: 0.5129
#
# Epoch 00017: val_loss improved from 1.08413 to 1.08348, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 18/80
# 1/1 - 0s - loss: 0.9491 - sign_accuracy: 0.5957 - val_loss: 1.0860 - val_sign_accuracy: 0.5092
#
# Epoch 00018: val_loss did not improve from 1.08348
# Epoch 19/80
# 1/1 - 0s - loss: 0.9444 - sign_accuracy: 0.5957 - val_loss: 1.0844 - val_sign_accuracy: 0.5018
#
# Epoch 00019: val_loss did not improve from 1.08348
# Epoch 20/80
# 1/1 - 0s - loss: 0.9336 - sign_accuracy: 0.6022 - val_loss: 1.0845 - val_sign_accuracy: 0.4797
#
# Epoch 00020: val_loss did not improve from 1.08348
# Epoch 21/80
# 1/1 - 0s - loss: 0.9223 - sign_accuracy: 0.6207 - val_loss: 1.0906 - val_sign_accuracy: 0.4649
#
# Epoch 00021: val_loss did not improve from 1.08348
# Epoch 22/80
# 1/1 - 0s - loss: 0.9164 - sign_accuracy: 0.6152 - val_loss: 1.0927 - val_sign_accuracy: 0.4834
#
# Epoch 00022: val_loss did not improve from 1.08348
# Epoch 23/80
# 1/1 - 0s - loss: 0.9132 - sign_accuracy: 0.6041 - val_loss: 1.0800 - val_sign_accuracy: 0.4982
#
# Epoch 00023: val_loss improved from 1.08348 to 1.07995, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 24/80
# 1/1 - 0s - loss: 0.9072 - sign_accuracy: 0.6068 - val_loss: 1.0572 - val_sign_accuracy: 0.4982
#
# Epoch 00024: val_loss improved from 1.07995 to 1.05719, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 25/80
# 1/1 - 0s - loss: 0.8991 - sign_accuracy: 0.6161 - val_loss: 1.0379 - val_sign_accuracy: 0.4908
#
# Epoch 00025: val_loss improved from 1.05719 to 1.03795, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 26/80
# 1/1 - 0s - loss: 0.8942 - sign_accuracy: 0.6290 - val_loss: 1.0283 - val_sign_accuracy: 0.5387
#
# Epoch 00026: val_loss improved from 1.03795 to 1.02829, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 27/80
# 1/1 - 0s - loss: 0.8932 - sign_accuracy: 0.6226 - val_loss: 1.0236 - val_sign_accuracy: 0.5351
#
# Epoch 00027: val_loss improved from 1.02829 to 1.02362, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 28/80
# 1/1 - 0s - loss: 0.8916 - sign_accuracy: 0.6263 - val_loss: 1.0193 - val_sign_accuracy: 0.5351
#
# Epoch 00028: val_loss improved from 1.02362 to 1.01925, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 29/80
# 1/1 - 0s - loss: 0.8865 - sign_accuracy: 0.6337 - val_loss: 1.0165 - val_sign_accuracy: 0.5424
#
# Epoch 00029: val_loss improved from 1.01925 to 1.01652, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 30/80
# 1/1 - 0s - loss: 0.8800 - sign_accuracy: 0.6318 - val_loss: 1.0187 - val_sign_accuracy: 0.5424
#
# Epoch 00030: val_loss did not improve from 1.01652
# Epoch 31/80
# 1/1 - 0s - loss: 0.8764 - sign_accuracy: 0.6355 - val_loss: 1.0233 - val_sign_accuracy: 0.5424
#
# Epoch 00031: val_loss did not improve from 1.01652
# Epoch 32/80
# 1/1 - 0s - loss: 0.8756 - sign_accuracy: 0.6309 - val_loss: 1.0238 - val_sign_accuracy: 0.5387
#
# Epoch 00032: val_loss did not improve from 1.01652
# Epoch 33/80
# 1/1 - 0s - loss: 0.8733 - sign_accuracy: 0.6346 - val_loss: 1.0196 - val_sign_accuracy: 0.5314
#
# Epoch 00033: val_loss did not improve from 1.01652
# Epoch 34/80
# 1/1 - 0s - loss: 0.8690 - sign_accuracy: 0.6374 - val_loss: 1.0157 - val_sign_accuracy: 0.5387
#
# Epoch 00034: val_loss improved from 1.01652 to 1.01568, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 35/80
# 1/1 - 0s - loss: 0.8655 - sign_accuracy: 0.6438 - val_loss: 1.0137 - val_sign_accuracy: 0.5351
#
# Epoch 00035: val_loss improved from 1.01568 to 1.01368, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 36/80
# 1/1 - 0s - loss: 0.8633 - sign_accuracy: 0.6448 - val_loss: 1.0120 - val_sign_accuracy: 0.5498
#
# Epoch 00036: val_loss improved from 1.01368 to 1.01204, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 37/80
# 1/1 - 0s - loss: 0.8608 - sign_accuracy: 0.6448 - val_loss: 1.0113 - val_sign_accuracy: 0.5572
#
# Epoch 00037: val_loss improved from 1.01204 to 1.01127, saving model to temp_model/gru7_oneoff_n90_6var_span4_X1.hdf5
# Epoch 38/80
# 1/1 - 0s - loss: 0.8574 - sign_accuracy: 0.6522 - val_loss: 1.0143 - val_sign_accuracy: 0.5498
#
# Epoch 00038: val_loss did not improve from 1.01127
# Epoch 39/80
# 1/1 - 0s - loss: 0.8545 - sign_accuracy: 0.6438 - val_loss: 1.0216 - val_sign_accuracy: 0.5535
#
# Epoch 00039: val_loss did not improve from 1.01127
# Epoch 40/80
# 1/1 - 0s - loss: 0.8524 - sign_accuracy: 0.6420 - val_loss: 1.0293 - val_sign_accuracy: 0.5314
#
# Epoch 00040: val_loss did not improve from 1.01127
# Epoch 41/80
# 1/1 - 0s - loss: 0.8502 - sign_accuracy: 0.6374 - val_loss: 1.0335 - val_sign_accuracy: 0.5351
#
# Epoch 00041: val_loss did not improve from 1.01127
# Epoch 42/80
# 1/1 - 0s - loss: 0.8470 - sign_accuracy: 0.6392 - val_loss: 1.0351 - val_sign_accuracy: 0.5351
#
# Epoch 00042: val_loss did not improve from 1.01127
# Epoch 43/80
# 1/1 - 0s - loss: 0.8436 - sign_accuracy: 0.6448 - val_loss: 1.0371 - val_sign_accuracy: 0.5351
#
# Epoch 00043: val_loss did not improve from 1.01127
# Epoch 44/80
# 1/1 - 0s - loss: 0.8413 - sign_accuracy: 0.6568 - val_loss: 1.0406 - val_sign_accuracy: 0.5351
#
# Epoch 00044: val_loss did not improve from 1.01127
# Epoch 45/80
# 1/1 - 0s - loss: 0.8395 - sign_accuracy: 0.6642 - val_loss: 1.0452 - val_sign_accuracy: 0.5314
#
# Epoch 00045: val_loss did not improve from 1.01127
# Epoch 46/80
# 1/1 - 0s - loss: 0.8371 - sign_accuracy: 0.6642 - val_loss: 1.0514 - val_sign_accuracy: 0.5240
#
# Epoch 00046: val_loss did not improve from 1.01127
# Epoch 47/80
# 1/1 - 0s - loss: 0.8342 - sign_accuracy: 0.6633 - val_loss: 1.0589 - val_sign_accuracy: 0.5129
#
# Epoch 00047: val_loss did not improve from 1.01127
# Epoch 48/80
# 1/1 - 0s - loss: 0.8318 - sign_accuracy: 0.6623 - val_loss: 1.0628 - val_sign_accuracy: 0.5166
#
# Epoch 00048: val_loss did not improve from 1.01127
# Epoch 49/80
# 1/1 - 0s - loss: 0.8297 - sign_accuracy: 0.6623 - val_loss: 1.0596 - val_sign_accuracy: 0.5240
#
# Epoch 00049: val_loss did not improve from 1.01127
# Epoch 50/80
# 1/1 - 0s - loss: 0.8270 - sign_accuracy: 0.6623 - val_loss: 1.0529 - val_sign_accuracy: 0.5314
#
# Epoch 00050: val_loss did not improve from 1.01127
# Epoch 51/80
# 1/1 - 0s - loss: 0.8245 - sign_accuracy: 0.6623 - val_loss: 1.0478 - val_sign_accuracy: 0.5424
#
# Epoch 00051: val_loss did not improve from 1.01127
# Epoch 52/80
# 1/1 - 0s - loss: 0.8223 - sign_accuracy: 0.6614 - val_loss: 1.0467 - val_sign_accuracy: 0.5424
#
# Epoch 00052: val_loss did not improve from 1.01127
# Epoch 53/80
# 1/1 - 0s - loss: 0.8199 - sign_accuracy: 0.6642 - val_loss: 1.0497 - val_sign_accuracy: 0.5351
#
# Epoch 00053: val_loss did not improve from 1.01127
# Epoch 54/80
# 1/1 - 0s - loss: 0.8171 - sign_accuracy: 0.6670 - val_loss: 1.0557 - val_sign_accuracy: 0.5387
#
# Epoch 00054: val_loss did not improve from 1.01127
# Epoch 55/80
# 1/1 - 0s - loss: 0.8146 - sign_accuracy: 0.6660 - val_loss: 1.0603 - val_sign_accuracy: 0.5351
#
# Epoch 00055: val_loss did not improve from 1.01127
# Epoch 56/80
# 1/1 - 0s - loss: 0.8125 - sign_accuracy: 0.6651 - val_loss: 1.0597 - val_sign_accuracy: 0.5387
#
# Epoch 00056: val_loss did not improve from 1.01127
# Epoch 57/80
# 1/1 - 0s - loss: 0.8100 - sign_accuracy: 0.6651 - val_loss: 1.0562 - val_sign_accuracy: 0.5387
#
# Epoch 00057: val_loss did not improve from 1.01127
# Epoch 58/80
# 1/1 - 0s - loss: 0.8076 - sign_accuracy: 0.6698 - val_loss: 1.0546 - val_sign_accuracy: 0.5461
#
# Epoch 00058: val_loss did not improve from 1.01127
# Epoch 59/80
# 1/1 - 0s - loss: 0.8053 - sign_accuracy: 0.6725 - val_loss: 1.0567 - val_sign_accuracy: 0.5424
#
# Epoch 00059: val_loss did not improve from 1.01127
# Epoch 60/80
# 1/1 - 0s - loss: 0.8027 - sign_accuracy: 0.6753 - val_loss: 1.0619 - val_sign_accuracy: 0.5277
#
# Epoch 00060: val_loss did not improve from 1.01127
# Epoch 61/80
# 1/1 - 0s - loss: 0.8002 - sign_accuracy: 0.6762 - val_loss: 1.0658 - val_sign_accuracy: 0.5240
#
# Epoch 00061: val_loss did not improve from 1.01127
# Epoch 62/80
# 1/1 - 0s - loss: 0.7979 - sign_accuracy: 0.6753 - val_loss: 1.0652 - val_sign_accuracy: 0.5351
#
# Epoch 00062: val_loss did not improve from 1.01127
# Epoch 63/80
# 1/1 - 0s - loss: 0.7954 - sign_accuracy: 0.6781 - val_loss: 1.0636 - val_sign_accuracy: 0.5424
#
# Epoch 00063: val_loss did not improve from 1.01127
# Epoch 64/80
# 1/1 - 0s - loss: 0.7929 - sign_accuracy: 0.6799 - val_loss: 1.0653 - val_sign_accuracy: 0.5424
#
# Epoch 00064: val_loss did not improve from 1.01127
# Epoch 65/80
# 1/1 - 0s - loss: 0.7905 - sign_accuracy: 0.6790 - val_loss: 1.0711 - val_sign_accuracy: 0.5351
#
# Epoch 00065: val_loss did not improve from 1.01127
# Epoch 66/80
# 1/1 - 0s - loss: 0.7879 - sign_accuracy: 0.6809 - val_loss: 1.0787 - val_sign_accuracy: 0.5351
#
# Epoch 00066: val_loss did not improve from 1.01127
# Epoch 67/80
# 1/1 - 0s - loss: 0.7855 - sign_accuracy: 0.6772 - val_loss: 1.0829 - val_sign_accuracy: 0.5277
#
# Epoch 00067: val_loss did not improve from 1.01127
# Epoch 68/80
# 1/1 - 0s - loss: 0.7831 - sign_accuracy: 0.6772 - val_loss: 1.0820 - val_sign_accuracy: 0.5203
#
# Epoch 00068: val_loss did not improve from 1.01127
# Epoch 69/80
# 1/1 - 0s - loss: 0.7805 - sign_accuracy: 0.6799 - val_loss: 1.0807 - val_sign_accuracy: 0.5166
#
# Epoch 00069: val_loss did not improve from 1.01127
# Epoch 70/80
# 1/1 - 0s - loss: 0.7780 - sign_accuracy: 0.6799 - val_loss: 1.0821 - val_sign_accuracy: 0.5203
#
# Epoch 00070: val_loss did not improve from 1.01127
# Epoch 71/80
# 1/1 - 0s - loss: 0.7755 - sign_accuracy: 0.6836 - val_loss: 1.0864 - val_sign_accuracy: 0.5129
#
# Epoch 00071: val_loss did not improve from 1.01127
# Epoch 72/80
# 1/1 - 0s - loss: 0.7728 - sign_accuracy: 0.6818 - val_loss: 1.0917 - val_sign_accuracy: 0.5129
#
# Epoch 00072: val_loss did not improve from 1.01127
# Epoch 73/80
# 1/1 - 0s - loss: 0.7702 - sign_accuracy: 0.6799 - val_loss: 1.0950 - val_sign_accuracy: 0.5203
#
# Epoch 00073: val_loss did not improve from 1.01127
# Epoch 74/80
# 1/1 - 0s - loss: 0.7675 - sign_accuracy: 0.6809 - val_loss: 1.0969 - val_sign_accuracy: 0.5277
#
# Epoch 00074: val_loss did not improve from 1.01127
# Epoch 75/80
# 1/1 - 0s - loss: 0.7648 - sign_accuracy: 0.6846 - val_loss: 1.0999 - val_sign_accuracy: 0.5314
#
# Epoch 00075: val_loss did not improve from 1.01127
# Epoch 76/80
# 1/1 - 0s - loss: 0.7622 - sign_accuracy: 0.6864 - val_loss: 1.1049 - val_sign_accuracy: 0.5277
#
# Epoch 00076: val_loss did not improve from 1.01127
# Epoch 77/80
# 1/1 - 0s - loss: 0.7594 - sign_accuracy: 0.6836 - val_loss: 1.1100 - val_sign_accuracy: 0.5240
#
# Epoch 00077: val_loss did not improve from 1.01127
# Epoch 78/80
# 1/1 - 0s - loss: 0.7567 - sign_accuracy: 0.6873 - val_loss: 1.1131 - val_sign_accuracy: 0.5240
#
# Epoch 00078: val_loss did not improve from 1.01127
# Epoch 79/80
# 1/1 - 0s - loss: 0.7539 - sign_accuracy: 0.6892 - val_loss: 1.1157 - val_sign_accuracy: 0.5240
#
# Epoch 00079: val_loss did not improve from 1.01127
# Epoch 80/80
# 1/1 - 0s - loss: 0.7511 - sign_accuracy: 0.6901 - val_loss: 1.1198 - val_sign_accuracy: 0.5351
#
# Epoch 00080: val_loss did not improve from 1.01127

# %%
# plot training history
hist = pd.DataFrame.from_dict(history.history)
# fig = go.Figure()

fig = make_subplots(rows=1, 
                    cols=2,
                    subplot_titles=("Train and Validation Loss per epoch", "Train and Validation Accuracy per epoch"))

# Plot Train and Validation Loss per epoch
fig.add_trace(go.Scatter(y=hist['loss'],line=dict(color='blue'),name='train_loss'), row=1, col=1)
fig.add_trace(go.Scatter(y=hist['val_loss'],line=dict(color='firebrick'),name='val_loss'), row=1, col=1)

# Plot Train and Validation Accuracy per epoch
fig.add_trace(go.Scatter(y=hist['sign_accuracy'], line=dict(color='blue'), name='train'), row=1, col=2)
fig.add_trace(go.Scatter(y=hist['val_sign_accuracy'], line=dict(color='firebrick'), name='val'), row=1, col=2)

# Set x and y axes title
fig.update_xaxes(title_text="Epoch", row=1, col=1)
fig.update_xaxes(title_text="Epoch", row=1, col=2)

fig.update_yaxes(title_text="Loss", row=1, col=1)
fig.update_yaxes(title_text="Accuracy", row=1, col=2)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="118fd96d-57ea-41bc-b573-34e9736437a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("118fd96d-57ea-41bc-b573-34e9736437a8")) {
#                     Plotly.newPlot(
#                         '118fd96d-57ea-41bc-b573-34e9736437a8',
#                         [{"line": {"color": "blue"}, "name": "train_loss", "type": "scatter", "xaxis": "x", "y": [1.4397300481796265, 1.2457473278045654, 1.1838066577911377, 1.1970412731170654, 1.169756293296814, 1.1006113290786743, 1.0702918767929077, 1.0820754766464233, 1.0761423110961914, 1.0375136137008667, 0.9981303215026855, 0.9837949275970459, 0.9884381294250488, 0.9856905341148376, 0.970191478729248, 0.9555282592773438, 0.950298547744751, 0.9490930438041687, 0.9443656802177429, 0.9336005449295044, 0.9222754240036011, 0.9163637757301331, 0.9132448434829712, 0.9072141647338867, 0.8991319537162781, 0.8941716551780701, 0.8931517004966736, 0.8915950655937195, 0.8865129947662354, 0.8800044655799866, 0.8763630986213684, 0.8755506277084351, 0.8733187317848206, 0.8690282106399536, 0.8654658794403076, 0.8632739186286926, 0.8607511520385742, 0.8574239015579224, 0.8545007109642029, 0.85244220495224, 0.8502108454704285, 0.8469588160514832, 0.8435657024383545, 0.8412501215934753, 0.8395131826400757, 0.8371326327323914, 0.8342025876045227, 0.8318095803260803, 0.8296828866004944, 0.8270108699798584, 0.8244805335998535, 0.8223387598991394, 0.8198907971382141, 0.8170855045318604, 0.8146398067474365, 0.8124703168869019, 0.8099716901779175, 0.8075668215751648, 0.8053432106971741, 0.8027377724647522, 0.8002020716667175, 0.7979336380958557, 0.7953786849975586, 0.7928639650344849, 0.7904865145683289, 0.787929356098175, 0.7854833006858826, 0.7830705046653748, 0.7804737091064453, 0.7779942750930786, 0.7754538655281067, 0.7728299498558044, 0.7702353000640869, 0.767536461353302, 0.7648407220840454, 0.7621675133705139, 0.759449303150177, 0.7566882371902466, 0.7538723349571228, 0.7510943412780762], "yaxis": "y"}, {"line": {"color": "firebrick"}, "name": "val_loss", "type": "scatter", "xaxis": "x", "y": [1.3965485095977783, 1.3844135999679565, 1.456019639968872, 1.4434632062911987, 1.3709843158721924, 1.2986257076263428, 1.25518000125885, 1.2266051769256592, 1.1863962411880493, 1.1531143188476562, 1.1502056121826172, 1.1649343967437744, 1.1636040210723877, 1.1350994110107422, 1.1009857654571533, 1.0841258764266968, 1.0834766626358032, 1.0860475301742554, 1.0843640565872192, 1.0845372676849365, 1.0906420946121216, 1.0926506519317627, 1.0799517631530762, 1.0571929216384888, 1.037947416305542, 1.0282906293869019, 1.0236155986785889, 1.019252896308899, 1.0165165662765503, 1.0187104940414429, 1.0233267545700073, 1.0237579345703125, 1.0196003913879395, 1.0156826972961426, 1.0136831998825073, 1.012039303779602, 1.0112653970718384, 1.0142966508865356, 1.0215811729431152, 1.0292648077011108, 1.0335198640823364, 1.0350626707077026, 1.0370674133300781, 1.040626883506775, 1.0452238321304321, 1.0513722896575928, 1.0588732957839966, 1.0628433227539062, 1.0596380233764648, 1.0528771877288818, 1.0478496551513672, 1.046712875366211, 1.0497196912765503, 1.0556854009628296, 1.0603387355804443, 1.0596996545791626, 1.0562278032302856, 1.0546424388885498, 1.0567083358764648, 1.061850666999817, 1.0658392906188965, 1.0652186870574951, 1.0636032819747925, 1.065311312675476, 1.0710502862930298, 1.0786701440811157, 1.0829110145568848, 1.0819952487945557, 1.080723762512207, 1.082125186920166, 1.0864394903182983, 1.091658592224121, 1.0949938297271729, 1.096867322921753, 1.099900245666504, 1.1049296855926514, 1.1100492477416992, 1.1130611896514893, 1.115744948387146, 1.1197715997695923], "yaxis": "y"}, {"line": {"color": "blue"}, "name": "train", "type": "scatter", "xaxis": "x2", "y": [0.5180388689041138, 0.5568917393684387, 0.5393154621124268, 0.543015718460083, 0.5457909107208252, 0.5578168630599976, 0.567992627620697, 0.5550416111946106, 0.5587419271469116, 0.5818686485290527, 0.5827937126159668, 0.5837187767028809, 0.5707678198814392, 0.5698427557945251, 0.5911193490028381, 0.5846438407897949, 0.6022201776504517, 0.5957446694374084, 0.5957446694374084, 0.6022201776504517, 0.6207215785980225, 0.6151711344718933, 0.6040703058242798, 0.606845498085022, 0.6160961985588074, 0.62 ...
#                         {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Train and Validation Loss per epoch", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}

# %% [markdown]
# # 5. Evaluate Model

# %%
# Generate result from model
_,_,train_result = generate_prediction(new_model,X_train,y_train)
_,_,test_result = generate_prediction(new_model,X_test,y_test,df_test.index[(input_timesteps+output_timesteps-1):])
_,_,test_result2 = generate_prediction(new_model,X_test2,y_test2,df_test2.index[(input_timesteps+output_timesteps-1):])
_,_,test_result3 = generate_prediction(new_model,X_test3,y_test3,df_test3.index[(input_timesteps+output_timesteps-1):])

# %% [markdown]
# ## 5.1 Train Result Evaluation

# %%
conf_matrix = confusion_matrix(train_result['true_bin'], train_result['pred_bin'])[::-1]
viz.display_confusion_matrix(conf_matrix, reverse_ylabel=True)

# %%
print(classification_report(train_result['true_bin'],train_result['pred_bin'], target_names=['Negatives','Positives']))
# Out:
#               precision    recall  f1-score   support
#
#    Negatives       0.62      0.68      0.65       676
#    Positives       0.64      0.57      0.61       676
#
#     accuracy                           0.63      1352
#    macro avg       0.63      0.63      0.63      1352
# weighted avg       0.63      0.63      0.63      1352

# %%
fig = px.scatter(train_result, x="pred", y="true", color="squared_hinge", 
                 trendline="ols",
                 title="Train Result",
                 width=800, height=800, hover_data=["date_str"])
fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc21debe-799e-4542-9089-341ba9ab5373" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc21debe-799e-4542-9089-341ba9ab5373")) {
#                     Plotly.newPlot(
#                         'dc21debe-799e-4542-9089-341ba9ab5373',
#                         [{"customdata": [["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012-05-01"], ["2012- ...

# %% [markdown]
# ## 5.2 Test Result Evaluation

# %%
conf_matrix2 = confusion_matrix(test_result['true_bin'],test_result['pred_bin'])[::-1]
viz.display_confusion_matrix(conf_matrix2, reverse_ylabel=True)
print(classification_report(test_result['pred_bin'], test_result['true_bin'], target_names=['Negatives','Positives']))
# Out:
#               precision    recall  f1-score   support
#
#    Negatives       0.85      0.60      0.70       193
#    Positives       0.39      0.70      0.51        71
#
#     accuracy                           0.63       264
#    macro avg       0.62      0.65      0.60       264
# weighted avg       0.72      0.63      0.65       264

# %%
test_pred_ter = np.where(test_result['pred'] < lower_thresh,-1,np.where(test_result['pred'] > upper_thresh,1,0))
test_true_ter = np.where(test_result['true'] < lower_thresh,-1,np.where(test_result['true'] > upper_thresh,1,0))
conf_matrix = confusion_matrix(test_true_ter,test_pred_ter)[::-1]
labels = ['Negatives','Hold','Positives']
sns.heatmap(conf_matrix, 
                annot=True, 
                cmap="Blues",
                fmt="d",vmin=0, 
                annot_kws={"size": 20}, 
                xticklabels = labels, 
                yticklabels= labels[::-1])
plt.xlabel('Predicted Values', fontsize = 12) # x-axis label with fontsize 15
plt.ylabel('Actual Values', fontsize = 12)
# Out:
# Text(30.5, 0.5, 'Actual Values')

# %%
# Plots high conviction result
high_conviction_result = pd.DataFrame(test_pred_ter, columns=['Test'])
high_conviction_result['True'] = test_true_ter

high_conviction_result = high_conviction_result[(high_conviction_result.Test != 0) & (high_conviction_result['True'] != 0)]

conf_matrix2 = confusion_matrix(high_conviction_result['True'],high_conviction_result['Test'])[::-1]
viz.display_confusion_matrix(conf_matrix2, reverse_ylabel=True)

# Prints classification report
print(classification_report(high_conviction_result['True'],high_conviction_result['Test'], target_names=['Negatives','Positives']))
# Out:
#               precision    recall  f1-score   support
#
#    Negatives       0.61      0.95      0.75        79
#    Positives       0.78      0.23      0.35        61
#
#     accuracy                           0.64       140
#    macro avg       0.70      0.59      0.55       140
# weighted avg       0.69      0.64      0.58       140

# %%
fig = px.scatter(test_result, x="pred", y="true", color="squared_hinge", 
                 trendline="ols",
                 title="Test Result",
                 width=800, height=800, hover_data=["date_str"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0ec406a-1bff-48fa-9a03-831aee775e53" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0ec406a-1bff-48fa-9a03-831aee775e53")) {
#                     Plotly.newPlot(
#                         'd0ec406a-1bff-48fa-9a03-831aee775e53',
#                         [{"customdata": [["2019-01-29"], ["2019-01-30"], ["2019-01-31"], ["2019-02-01"], ["2019-02-04"], ["2019-02-05"], ["2019-02-06"], ["2019-02-07"], ["2019-02-08"], ["2019-02-11"], ["2019-02-12"], ["2019-02-13"], ["2019-02-14"], ["2019-02-15"], ["2019-02-18"], ["2019-02-19"], ["2019-02-20"], ["2019-02-21"], ["2019-02-22"], ["2019-02-25"], ["2019-02-26"], ["2019-02-27"], ["2019-02-28"], ["2019-03-01"], ["2019-03-04"], ["2019-03-05"], ["2019-03-06"], ["2019-03-07"], ["2019-03-08"], ["2019-03-11"], ["2019-03-12"], ["2019-03-13"], ["2019-03-14"], ["2019-03-15"], ["2019-03-18"], ["2019-03-19"], ["2019-03-20"], ["2019-03-21"], ["2019-03-22"], ["2019-03-25"], ["2019-03-26"], ["2019-03-27"], ["2019-03-28"], ["2019-03-29"], ["2019-04-01"], ["2019-04-02"], ["2019-04-03"], ["2019-04-04"], ["2019-04-05"], ["2019-04-08"], ["2019-04-09"], ["2019-04-10"], ["2019-04-11"], ["2019-04-12"], ["2019-04-15"], ["2019-04-16"], ["2019-04-17"], ["2019-04-18"], ["2019-04-19"], ["2019-04-22"], ["2019-04-23"], ["2019-04-24"], ["2019-04-25"], ["2019-04-26"], ["2019-04-29"], ["2019-04-30"], ["2019-05-01"], ["2019-05-02"], ["2019-05-03"], ["2019-05-06"], ["2019-05-07"], ["2019-05-08"], ["2019-05-09"], ["2019-05-10"], ["2019-05-13"], ["2019-05-14"], ["2019-05-15"], ["2019-05-16"], ["2019-05-17"], ["2019-05-20"], ["2019-05-21"], ["2019-05-22"], ["2019-05-23"], ["2019-05-24"], ["2019-05-27"], ["2019-05-28"], ["2019-05-29"], ["2019-05-30"], ["2019-05-31"], ["2019-06-03"], ["2019-06-04"], ["2019-06-05"], ["2019-06-06"], ["2019-06-07"], ["2019-06-10"], ["2019-06-11"], ["2019-06-12"], ["2019-06-13"], ["2019-06-14"], ["2019-06-17"], ["2019-06-18"], ["2019-06-19"], ["2019-06-20"], ["2019-06-21"], ["2019-06-24"], ["2019-06-25"], ["2019-06-26"], ["2019-06-27"], ["2019-06-28"], ["2019-07-01"], ["2019-07-02"], ["2019-07-03"], ["2019-07-04"], ["2019-07-05"], ["2019-07-08"], ["2019-07-09"], ["2019-07-10"], ["2019-07-11"], ["2019-07-12"], ["2019-07-15"], ["2019-07-16"], ["2019-07-17"], ["2019-07-18"], ["2019-07-19"], ["2019-07-22"], ["2019-07-23"], ["2019-07-24"], ["2019-07-25"], ["2019-07-26"], ["2019-07-29"], ["2019-07-30"], ["2019-07-31"], ["2019-08-01"], ["2019-08-02"], ["2019-08-05"], ["2019-08-06"], ["2019-08-07"], ["2019-08-08"], ["2019-08-09"], ["2019-08-12"], ["2019-08-13"], ["2019-08-14"], ["2019-08-15"], ["2019-08-16"], ["2019-08-19"], ["2019-08-20"], ["2019-08-21"], ["2019-08-22"], ["2019-08-23"], ["2019-08-26"], ["2019-08-27"], ["2019-08-28"], ["2019-08-29"], ["2019-08-30"], ["2019-09-02"], ["2019-09-03"], ["2019-09-04"], ["2019-09-05"], ["2019-09-06"], ["2019-09-09"], ["2019-09-10"], ["2019-09-11"], ["2019-09-12"], ["2019-09-13"], ["2019-09-16"], ["2019-09-17"], ["2019-09-18"], ["2019-09-19"], ["2019-09-20"], ["2019-09-23"], ["2019-09-24"], ["2019-09-25"], ["2019-09-26"], ["2019-09-27"], ["2019-09-30"], ["2019-10-01"], ["2019-10-02"], ["2019-10-03"], ["2019-10-04"], ["2019-10-07"], ["2019-10-08"], ["2019-10-09"], ["2019-10-10"], ["2019-10-11"], ["2019-10-14"], ["2019-10-15"], ["2019-10-16"], ["2019-10-17"], ["2019-10-18"], ["2019-10-21"], ["2019-10-22"], ["2019-10-23"], ["2019-10-24"], ["2019-10-25"], ["2019-10-28"], ["2019-10-29"], ["2019-10-30"], ["2019-10-31"], ["2019-11-01"], ["2019-11-04"], ["2019-11-05"], ["2019-11-06"], ["2019-11-07"], ["2019-11-08"], ["2019-11-11"], ["2019-11-12"], ["2019-11-13"], ["2019-11-14"], ["2019-11-15"], ["2019-11-18"], ["2019-11-19"], ["2019-11-20"], ["2019-11-21"], ["2019-11-22"], ["2019-11-25"], ["2019-11-26"], ["2019-11-27"], ["2019-11-28"], ["2019-11-29"], ["2019-12-02"], ["2019-12-03"], ["2019-12-04"], ["2019-12-05"], ["2019-12-06"], ["2019-12-09"], ["2019-12-10"], ["2019-12-11"], ["2019-12-12"], ["2019-12-13"], ["2019-12-16"], ["2019-12-17"], ["2019-12-18"], ["2019-12-19"], ["2019-12-20"], ["2019-12-23"], ["2019-12-24"], ["2019-12-25"], ["2019-12-26"], ["2019-12-27"], ["2019-12-30"], ["2019-12-31"], ["2020-01-01"], ["2020-01-02"], ["2020-01-03"], ["2020-01-06"], ["2020-01-07"], ["2020-01-08"], ["2020- ...

# %% [markdown]
# #  6. Run Trading Simulation

# %%
def plot_returns(df):
    fig, ax = plt.subplots(3, 1, sharex=True, figsize=[24, 12])
    
    # Add patch as legend
    red_patch = mpl.patches.Patch(color='#bb3f3f', label='Sell')
    green_patch = mpl.patches.Patch(color='#008000', label='Buy')
    
    # Closing price chart
    close = 100*df['Close']/df['Close'][0]
    sns.lineplot(data=close, ax=ax[0])
    ax[0].set_ylabel('Closing Price')
    buys = df.loc[df.position == 'Buy'] # mark buy transactions
    sells = df.loc[df.position == 'Sell'] # mark sell transactions
    
    # Add dashed line on last closing price
    last_closing_price = close[-1]
    ax[0].axhline(last_closing_price, ls='--',linewidth=1, color='m')
    ax[0].plot(buys.index, close.loc[buys.index], '.', markersize=8, color='g', label='buy')
    ax[0].plot(sells.index, close.loc[sells.index], '.', markersize=8, color='r', label='sell')
    ax[0].annotate((last_closing_price).round(2),xy=(1,last_closing_price),xycoords=('axes fraction','data'),ha='left',va='center',color='black')
    ax[0].grid(True)
    ax[0].legend(handles=[red_patch, green_patch])

    # Price change chart
    sns.lineplot(data=df[['target','pred']], ax=ax[1])
    ax[1].set_ylabel('target'.format(3))
    ax[1].grid(True)

    # Portfolio value
    port_value = df['value'] / df['value'][0]
    sns.lineplot(data=port_value, ax=ax[2])
    ax[2].set_ylabel('Portfolio Value')
    last_value = port_value[-1]
    ax[2].axhline(last_value, ls='--',linewidth=1, color='m')
    ax[2].annotate((last_value).round(2),xy=(1,last_value),xycoords=('axes fraction','data'),ha='left',va='center',color='black')
    ax[2].grid(True)

# %%
test_date = df_test[(input_timesteps+output_timesteps-1):].index
res = pd.DataFrame(test_date)
res['pred'] = test_result['pred']
res = res.set_index(['Date'])
res = df_test.merge(res, how='inner', left_index=True, right_index=True).copy()

test_returns = tm.simulate_position(res,0.15,-0.3,buy_fee=0.0025,sell_fee=0.003)#dp.generate_returns(res)
plot_returns(test_returns)

# %%
test_date2 = df_test2[(input_timesteps+output_timesteps-1):].index
res = pd.DataFrame(test_date2)
res['pred'] = test_result2['pred']
res = res.set_index(['Date'])

res = df_test2.merge(res, how='inner', left_index=True, right_index=True).copy()

test_returns2 = tm.simulate_position(res,lower_thresh,upper_thresh)#dp.generate_returns(res)
plot_returns(test_returns2)
